# %% [markdown]
# # 0. 미션 소개 및 주제

# %% [markdown]
# ### 미션 목표

# %% [markdown]
# 이번 미션의 최종 목표는 RMSLE (Root Mean Squared Logarithmic Error)를 최대한 낮추는 것입니다.
#
# 다양한 머신러닝 모델과 전략을 실험하여 가장 정확한 수요 예측 모델을 개발하고, 그 결과를 보고서에 담아 보세요!
#
# -> 보고서를 따로 만들지 말고, 노트북을 잘 정리하기

# %% [markdown]
# ### 미션 방향성

# %% [markdown]
# 먼저 EDA와 데이터 전처리를 통하여, 데이터를 다듬고, 데이터를 분석한다.
#
# 그 다음, 배운 기본 지도 학습 알고리즘인 선형회귀, 다중회귀, 로지스틱회귀(제외), L1, L2정규화를 이용하여
#
# RMSLE를 비교하며 적합한 모델을 직접 확인해보고,
#
# 하이퍼 파라미터를 통하여 직접 확인한 수치가 맞는지 비교를 한다.
#
# 최종적으로, 적합한 수요 예측 모델로 test 결과를 예측한다.

# %% [markdown]
# ### 데이터 컬럼 설명
#
# | 컬럼명          | 데이터 타입   | 설명                                                |
# | ------------ | -------- | ------------------------------------------------- |
# | `datetime`   | datetime | 자전거 대여 기록의 날짜 및 시간<br>예: `2011-01-01 00:00:00`    |
# | `season`     | int      | 계절<br>(1: 봄, 2: 여름, 3: 가을, 4: 겨울)                 |
# | `holiday`    | int      | 공휴일 여부<br>(0: 평일, 1: 공휴일)                         |
# | `workingday` | int      | 근무일 여부<br>(0: 주말/공휴일, 1: 근무일)                     |
# | `weather`    | int      | 날씨 상황<br>(1: 맑음, 2: 구름낌/안개, 3: 약간의 비/눈, 4: 폭우/폭설) |
# | `temp`       | float    | 실측 온도 (섭씨)                                        |
# | `atemp`      | float    | 체감 온도 (섭씨)                                        |
# | `humidity`   | int      | 습도 (%)                                            |
# | `windspeed`  | float    | 풍속 (m/s)                                          |
# | `casual`     | int      | 등록되지 않은 사용자의 대여 수                                 |
# | `registered` | int      | 등록된 사용자의 대여 수                                     |
# | `count`      | int      | **총 대여 수 (종속 변수)**                                |

# %% [markdown]
# ### 기본 세팅

# %%
# 기본 세팅

# 필요한 라이브러리 불러오기
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.model_selection import train_test_split
from sklearn.metrics import root_mean_squared_error
import optuna

# 경고 안보이게 하기
import warnings
from scipy.linalg import LinAlgWarning
warnings.filterwarnings("ignore", category=LinAlgWarning)

# 한글 폰트
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# 파일 불러오기
test_df = pd.read_csv('test.csv')
train_df = pd.read_csv('train.csv')



# 이번 미션 평가지표 RMSLE 
def rmsle(y_true, y_pred, convertExp=True):
    if convertExp:
        y_true = np.exp(y_true)
        y_pred = np.exp(y_pred)
    return np.sqrt(np.mean(np.power(np.log1p(y_pred) - np.log1p(y_true), 2))) # np.power(a, b) : a^b
# y는 log1p 변환값 (log1p : log(1+x))

# rmsle_lr = rmsle(np.expm1(y), np.expm1(pred_gs), convertExp=False)
# print("RMSLE:", rmsle_lr)

# %% [markdown]
# # 1. EDA

# %% [markdown]
# ## - 기본 정보 확인

# %%
# 기본 정보 확인
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %%
# 기본 정보 확인
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6493 entries, 0 to 6492
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    6493 non-null   object
#  1   season      6493 non-null   int64
#  2   holiday     6493 non-null   int64
#  3   workingday  6493 non-null   int64
#  4   weather     6493 non-null   int64
#  5   temp        6493 non-null   float64
#  6   atemp       6493 non-null   float64
#  7   humidity    6493 non-null   int64
#  8   windspeed   6493 non-null   float64
# dtypes: float64(3), int64(5), object(1)
# memory usage: 456.7+ KB

# %%
# 기본 정보 확인
train_df.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
# 기본 정보 확인
test_df.head()
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1  2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2  2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3  2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4  2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed
# 0        56    26.0027
# 1        56     0.0000
# 2        56     0.0000
# 3        56    11.0014
# 4        56    11.0014

# %%
# 기본 정보 확인
train_df.describe(include='all')
# Out:
#                    datetime        season       holiday    workingday  \
# count                 10886  10886.000000  10886.000000  10886.000000
# unique                10886           NaN           NaN           NaN
# top     2011-01-01 00:00:00           NaN           NaN           NaN
# freq                      1           NaN           NaN           NaN
# mean                    NaN      2.506614      0.028569      0.680875
# std                     NaN      1.116174      0.166599      0.466159
# min                     NaN      1.000000      0.000000      0.000000
# 25%                     NaN      2.000000      0.000000      0.000000
# 50%                     NaN      3.000000      0.000000      1.000000
# 75%                     NaN      4.000000      0.000000      1.000000
# max                     NaN      4.000000      1.000000      1.000000
#
#              weather         temp         atemp      humidity     windspeed  \
# count   10886.000000  10886.00000  10886.000000  10886.000000  10886.000000
# unique           NaN          NaN           NaN           NaN           NaN
# top              NaN          NaN           NaN           NaN           NaN
# freq             NaN          NaN           NaN           NaN           NaN
# mean        1.418427     20.23086     23.655084     61.886460     12.799395
# std         0.633839      7.79159      8.474601     19.245033      8.164537
# min         1.000000      0.82000      0.760000      0.000000      0.000000
# 25%         1.000000     13.94000     16.665000     47.000000      7.001500
# 50%         1.000000     20.50000     24.240000     62.000000     12.998000
# 75%         2.000000     26.24000     31.060000     77.000000     16.997900
# max         4.000000     41.00000     45.455000    100.000000     56.996900
#
#               casual    registered         count
# count   10886.000000  10886.000000  10886.000000
# unique           NaN           NaN           NaN
# top              NaN           NaN           NaN
# freq             NaN           NaN           NaN
# mean       36.021955    155.552177    191.574132
# std        49.960477    151.039033    181.144454
# min         0.000000      0.000000      1.000000
# 25%         4.000000     36.000000     42.000000
# 50%        17.000000    118.000000    145.000000
# 75%        49.000000    222.000000    284.000000
# max       367.000000    886.000000    977.000000

# %%
# 기본 정보 확인
test_df.describe(include='all')
# Out:
#                    datetime       season      holiday   workingday  \
# count                  6493  6493.000000  6493.000000  6493.000000
# unique                 6493          NaN          NaN          NaN
# top     2011-01-20 00:00:00          NaN          NaN          NaN
# freq                      1          NaN          NaN          NaN
# mean                    NaN     2.493300     0.029108     0.685815
# std                     NaN     1.091258     0.168123     0.464226
# min                     NaN     1.000000     0.000000     0.000000
# 25%                     NaN     2.000000     0.000000     0.000000
# 50%                     NaN     3.000000     0.000000     1.000000
# 75%                     NaN     3.000000     0.000000     1.000000
# max                     NaN     4.000000     1.000000     1.000000
#
#             weather         temp        atemp     humidity    windspeed
# count   6493.000000  6493.000000  6493.000000  6493.000000  6493.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean       1.436778    20.620607    24.012865    64.125212    12.631157
# std        0.648390     8.059583     8.782741    19.293391     8.250151
# min        1.000000     0.820000     0.000000    16.000000     0.000000
# 25%        1.000000    13.940000    16.665000    49.000000     7.001500
# 50%        1.000000    21.320000    25.000000    65.000000    11.001400
# 75%        2.000000    27.060000    31.060000    81.000000    16.997900
# max        4.000000    40.180000    50.000000   100.000000    55.998600

# %% [markdown]
# ## - 결측값 확인

# %%
# 결측값 확인
train_df.isna().sum()
# Out:
# datetime      0
# season        0
# holiday       0
# workingday    0
# weather       0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# casual        0
# registered    0
# count         0
# dtype: int64

# %%
# 결측값 확인
test_df.isna().sum()
# Out:
# datetime      0
# season        0
# holiday       0
# workingday    0
# weather       0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# dtype: int64

# %% [markdown]
# ## - 중복값 확인

# %%
# 중복값 확인
train_df[train_df.duplicated(keep='first')]
# Out:
# Empty DataFrame
# Columns: [datetime, season, holiday, workingday, weather, temp, atemp, humidity, windspeed, casual, registered, count]
# Index: []

# %%
# 중복값 확인
test_df[test_df.duplicated(keep='first')]
# Out:
# Empty DataFrame
# Columns: [datetime, season, holiday, workingday, weather, temp, atemp, humidity, windspeed]
# Index: []

# %% [markdown]
# - train 데이터와 test 데이터 모두 결측값, 중복값은 없음.
#
# 이상치는 데이터 전처리에서 발견시 처리예정

# %% [markdown]
# # 2. 데이터 전처리

# %% [markdown]
# ### 수치형 데이터

# %%
# 수치형 데이터
num_features = ['temp','atemp','humidity','windspeed']

# %%
# 시각화
for col in num_features:
    plt.figure(figsize=(3,3))
    sns.histplot(test_df[col], kde=True)
    plt.title(col)
    plt.show()

# %% [markdown]
# - windspeed는 분포가 치우쳐져 있어서 안정화를 위해 로그 변환
# - 나머지는 표준화 진행

# %%
# 목표변수 시각화
plt.figure(figsize=(3,3))
sns.histplot(train_df['count'], kde=True)
plt.title('Count')
plt.show()

# %% [markdown]
# - count(목표변수)도 로그 변환

# %%
# 로그 변환
train_df['windspeed'] = np.log1p(train_df['windspeed'])
train_df['count'] = np.log1p(train_df['count'])
test_df['windspeed'] = np.log1p(test_df['windspeed'])

# 표준화
standard_scaler = StandardScaler()
standard_features = ['temp', 'atemp', 'humidity']

train_df[standard_features] = standard_scaler.fit_transform(train_df[standard_features])
test_df[standard_features] = standard_scaler.transform(test_df[standard_features])

# %% [markdown]
# ### 범주형 데이터

# %%
# 범주형 데이터 
cat_features = ['season', 'holiday', 'workingday', 'weather']

# %%
# 각 데이터 고유값 확인
print(train_df['season'].value_counts())
print(train_df['holiday'].value_counts())
print(train_df['workingday'].value_counts())
print(train_df['weather'].value_counts())
# Out:
# season
# 4    2734
# 2    2733
# 3    2733
# 1    2686
# Name: count, dtype: int64
# holiday
# 0    10575
# 1      311
# Name: count, dtype: int64
# workingday
# 1    7412
# 0    3474
# Name: count, dtype: int64
# weather
# 1    7192
# 2    2834
# 3     859
# 4       1
# Name: count, dtype: int64

# %%
# weather 4인 데이터량이 부족하여 drop하기
train_df = train_df[train_df['weather'] != 4]
train_df['weather'].value_counts()
# Out:
# weather
# 1    7192
# 2    2834
# 3     859
# Name: count, dtype: int64

# %%
# 인코딩 
train_encoded_df = pd.get_dummies(train_df, columns=cat_features, drop_first=True)
test_encoded_df = pd.get_dummies(test_df, columns=cat_features, drop_first=True)

# %%
# train과 test의 컬럼 불일치를 방지 

train_encoded_df, test_encoded_df = train_encoded_df.align(test_encoded_df, join='left', axis=1, fill_value=0)

# %% [markdown]
# ### 날짜형 데이터

# %%
# 날짜형 데이터 타입 변환
train_encoded_df['datetime'] = pd.to_datetime(train_encoded_df['datetime'])
test_encoded_df['datetime'] = pd.to_datetime(test_encoded_df['datetime'])

# %%
# 날짜형 데이터 열 추가

train_encoded_df['year'] = train_encoded_df['datetime'].dt.year
train_encoded_df['month'] = train_encoded_df['datetime'].dt.month
train_encoded_df['day'] = train_encoded_df['datetime'].dt.day
train_encoded_df['hour'] = train_encoded_df['datetime'].dt.hour
train_encoded_df['weekday'] = train_encoded_df['datetime'].dt.weekday

test_encoded_df['year'] = test_encoded_df['datetime'].dt.year
test_encoded_df['month'] = test_encoded_df['datetime'].dt.month
test_encoded_df['day'] = test_encoded_df['datetime'].dt.day
test_encoded_df['hour'] = test_encoded_df['datetime'].dt.hour
test_encoded_df['weekday'] = test_encoded_df['datetime'].dt.weekday  # 시작 요일 : 월(0)

# %% [markdown]
# ### 분석용 자료 생성

# %% [markdown]
# 위에서 데이터를 로그변환과 표준화 처리하였기에,
#
# 1. 이를 재변환해서 데이터 분석 하고, 이를 다시 변환한 값을 모델링 하는 것보다
#
# 2. 변환한 값 자체의 해석한 내용을 표기하는 것보다
#
# -> 분석용 자료를 만들어서 분석하는게 낫다고 판단.

# %%
# 분석용 자료 불러오기
analysis_df = pd.read_csv('train.csv')

analysis_df['datetime'] = pd.to_datetime(analysis_df['datetime'])

analysis_df['year'] = analysis_df['datetime'].dt.year
analysis_df['month'] = analysis_df['datetime'].dt.month
analysis_df['day'] = analysis_df['datetime'].dt.day
analysis_df['hour'] = analysis_df['datetime'].dt.hour
analysis_df['weekday'] = analysis_df['datetime'].dt.weekday

# %% [markdown]
# ### 적용된 데이터 확인

# %%
# 적용된 데이터 확인하기
train_encoded_df.head()
# Out:
#              datetime      temp     atemp  humidity  windspeed  casual  \
# 0 2011-01-01 00:00:00 -1.333661 -1.092737  0.993213        0.0       3
# 1 2011-01-01 01:00:00 -1.438907 -1.182421  0.941249        0.0       8
# 2 2011-01-01 02:00:00 -1.438907 -1.182421  0.941249        0.0       5
# 3 2011-01-01 03:00:00 -1.333661 -1.092737  0.681430        0.0       3
# 4 2011-01-01 04:00:00 -1.333661 -1.092737  0.681430        0.0       0
#
#    registered     count  season_2  season_3  season_4  holiday_1  \
# 0          13  2.833213     False     False     False      False
# 1          32  3.713572     False     False     False      False
# 2          27  3.496508     False     False     False      False
# 3          10  2.639057     False     False     False      False
# 4           1  0.693147     False     False     False      False
#
#    workingday_1  weather_2  weather_3  year  month  day  hour  weekday
# 0         False      False      False  2011      1    1     0        5
# 1         False      False      False  2011      1    1     1        5
# 2         False      False      False  2011      1    1     2        5
# 3         False      False      False  2011      1    1     3        5
# 4         False      False      False  2011      1    1     4        5

# %%
# 적용된 데이터 확인하기
test_encoded_df.head()
# Out:
#              datetime      temp     atemp  humidity  windspeed  casual  \
# 0 2011-01-20 00:00:00 -1.228414 -1.450292 -0.305883   3.295937       0
# 1 2011-01-20 01:00:00 -1.228414 -1.182421 -0.305883   0.000000       0
# 2 2011-01-20 02:00:00 -1.228414 -1.182421 -0.305883   0.000000       0
# 3 2011-01-20 03:00:00 -1.228414 -1.271515 -0.305883   2.485023       0
# 4 2011-01-20 04:00:00 -1.228414 -1.271515 -0.305883   2.485023       0
#
#    registered  count  season_2  season_3  season_4  holiday_1  workingday_1  \
# 0           0      0     False     False     False      False          True
# 1           0      0     False     False     False      False          True
# 2           0      0     False     False     False      False          True
# 3           0      0     False     False     False      False          True
# 4           0      0     False     False     False      False          True
#
#    weather_2  weather_3  year  month  day  hour  weekday
# 0      False      False  2011      1   20     0        3
# 1      False      False  2011      1   20     1        3
# 2      False      False  2011      1   20     2        3
# 3      False      False  2011      1   20     3        3
# 4      False      False  2011      1   20     4        3

# %%
# 적용된 데이터 확인하기
train_encoded_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10885 entries, 0 to 10885
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   datetime      10885 non-null  datetime64[ns]
#  1   temp          10885 non-null  float64
#  2   atemp         10885 non-null  float64
#  3   humidity      10885 non-null  float64
#  4   windspeed     10885 non-null  float64
#  5   casual        10885 non-null  int64
#  6   registered    10885 non-null  int64
#  7   count         10885 non-null  float64
#  8   season_2      10885 non-null  bool
#  9   season_3      10885 non-null  bool
#  10  season_4      10885 non-null  bool
#  11  holiday_1     10885 non-null  bool
#  12  workingday_1  10885 non-null  bool
#  13  weather_2     10885 non-null  bool
#  14  weather_3     10885 non-null  bool
#  15  year          10885 non-null  int32
#  16  month         10885 non-null  int32
#  17  day           10885 non-null  int32
#  18  hour          10885 non-null  int32
#  19  weekday       10885 non-null  int32
# dtypes: bool(7), datetime64[ns](1), float64(5), int32(5), int64(2)
# memory usage: 1.0 MB

# %%
# 적용된 데이터 확인하기
test_encoded_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6493 entries, 0 to 6492
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   datetime      6493 non-null   datetime64[ns]
#  1   temp          6493 non-null   float64
#  2   atemp         6493 non-null   float64
#  3   humidity      6493 non-null   float64
#  4   windspeed     6493 non-null   float64
#  5   casual        6493 non-null   int64
#  6   registered    6493 non-null   int64
#  7   count         6493 non-null   int64
#  8   season_2      6493 non-null   bool
#  9   season_3      6493 non-null   bool
#  10  season_4      6493 non-null   bool
#  11  holiday_1     6493 non-null   bool
#  12  workingday_1  6493 non-null   bool
#  13  weather_2     6493 non-null   bool
#  14  weather_3     6493 non-null   bool
#  15  year          6493 non-null   int32
#  16  month         6493 non-null   int32
#  17  day           6493 non-null   int32
#  18  hour          6493 non-null   int32
#  19  weekday       6493 non-null   int32
# dtypes: bool(7), datetime64[ns](1), float64(4), int32(5), int64(3)
# memory usage: 577.1 KB

# %%
# 적용된 데이터 확인하기
train_encoded_df.describe(include='all')
# Out:
#                              datetime          temp         atemp  \
# count                           10885  10885.000000  10885.000000
# unique                            NaN           NaN           NaN
# top                               NaN           NaN           NaN
# freq                              NaN           NaN           NaN
# mean    2011-12-27 05:54:35.222783744      0.000142      0.000133
# min               2011-01-01 00:00:00     -2.491372     -2.701736
# 25%               2011-07-02 07:00:00     -0.807428     -0.824865
# 50%               2012-01-01 20:00:00      0.034544      0.069023
# 75%               2012-07-01 13:00:00      0.771270      0.873818
# max               2012-12-19 23:00:00      2.665707      2.572501
# std                               NaN      0.999982      0.999995
#
#             humidity     windspeed        casual    registered         count  \
# count   10885.000000  10885.000000  10885.000000  10885.000000  10885.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       -0.000115      2.327429     36.024713    155.551952      4.591316
# min        -3.215858      0.000000      0.000000      0.000000      0.693147
# 25%        -0.773558      2.079629      4.000000     36.000000      3.761200
# 50%         0.005900      2.638914     17.000000    118.000000      4.983607
# 75%         0.785358      2.890255     49.000000    222.000000      5.652489
# max         1.980526      4.060390    367.000000    886.000000      6.885510
# std         1.000020      0.956314     49.961943    151.045970      1.419511
#
#        season_2 season_3 season_4 holiday_1 workingday_1 weather_2 weather_3  \
# count     10885    10885    10885     10885        10885     10885     10885
# unique        2        2        2         2            2         2         2
# top       False    False    False     False         True     False     False
# freq       8152     8152     8151     10574         7411      8051     10026
# mean        NaN      NaN      NaN       NaN          NaN       NaN       NaN
# min         NaN      NaN      NaN       NaN          NaN       NaN       NaN
# 25%         NaN      NaN      NaN       NaN          NaN       NaN       NaN
# 50%         NaN      NaN      NaN       NaN          NaN       NaN       NaN
# 75%         NaN      NaN      NaN       NaN          NaN       NaN       NaN
# max         NaN      NaN      NaN       NaN          NaN       NaN       NaN
# std         NaN      NaN      NaN       NaN          NaN       NaN       NaN
#
#                 year         month           day          hour       weekday
# count   10885.000000  10885.000000  10885.000000  10885.000000  10885.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean     2011.501883      6.522003      9.992650     11.541020      3.014240
# min      2011.000000      1.000000      1.000000      0.000000      0.000000
# 25%      2011.000000      4.000000      5.000000      6.000000      1.000000
# 50%      2012.000000      7.000000     10.000000     12.000000      3.000000
# 75%      2012.000000     10.000000     15.000000     18.000000      5.000000
# max      2012.000000     12.000000     19.000000     23.000000      6.000000
# std         0.500019      3.444125      5.476852      6.915879      2.004469

# %%
# 적용된 데이터 확인하기
test_encoded_df.describe(include='all')
# Out:
#                              datetime         temp        atemp     humidity  \
# count                            6493  6493.000000  6493.000000  6493.000000
# unique                            NaN          NaN          NaN          NaN
# top                               NaN          NaN          NaN          NaN
# freq                              NaN          NaN          NaN          NaN
# mean    2012-01-13 09:27:47.765285632     0.050024     0.042220     0.116334
# min               2011-01-20 00:00:00    -2.491372    -2.791420    -2.384437
# 25%               2011-07-22 15:00:00    -0.807428    -0.824865    -0.669630
# 50%               2012-01-20 23:00:00     0.139790     0.158707     0.161792
# 75%               2012-07-20 17:00:00     0.876516     0.873818     0.993213
# max               2012-12-31 23:00:00     2.560460     3.108834     1.980526
# std                               NaN     1.034443     1.036408     1.002559
#
#           windspeed  casual  registered   count season_2 season_3 season_4  \
# count   6493.000000  6493.0      6493.0  6493.0     6493     6493     6493
# unique          NaN     NaN         NaN     NaN        2        2        2
# top             NaN     NaN         NaN     NaN    False    False    False
# freq            NaN     NaN         NaN     NaN     4817     4730     4995
# mean       2.294061     0.0         0.0     0.0      NaN      NaN      NaN
# min        0.000000     0.0         0.0     0.0      NaN      NaN      NaN
# 25%        2.079629     0.0         0.0     0.0      NaN      NaN      NaN
# 50%        2.485023     0.0         0.0     0.0      NaN      NaN      NaN
# 75%        2.890255     0.0         0.0     0.0      NaN      NaN      NaN
# max        4.043027     0.0         0.0     0.0      NaN      NaN      NaN
# std        0.990793     0.0         0.0     0.0      NaN      NaN      NaN
#
#        holiday_1 workingday_1 weather_2 weather_3         year        month  \
# count       6493         6493      6493      6493  6493.000000  6493.000000
# unique         2            2         2         2          NaN          NaN
# top        False         True     False     False          NaN          NaN
# freq        6304         4453      4783      5933          NaN          NaN
# mean         NaN          NaN       NaN       NaN  2011.503619     6.565070
# min          NaN          NaN       NaN       NaN  2011.000000     1.000000
# 25%          NaN          NaN       NaN       NaN  2011.000000     4.000000
# 50%          NaN          NaN       NaN       NaN  2012.000000     7.000000
# 75%          NaN          NaN       NaN       NaN  2012.000000    10.000000
# max          NaN          NaN       NaN       NaN  2012.000000    12.000000
# std          NaN          NaN       NaN       NaN     0.500025     3.429462
#
#                 day         hour      weekday
# count   6493.000000  6493.000000  6493.000000
# unique          NaN          NaN          NaN
# top             NaN          NaN          NaN
# freq            NaN          NaN          NaN
# mean      25.224550    11.555367     3.007239
# min       20.000000     0.000000     0.000000
# 25%       22.000000     6.000000     1.000000
# 50%       25.000000    12.000000     3.000000
# 75%       28.000000    18.000000     5.000000
# max       31.000000    23.000000     6.000000
# std        3.339411     6.912526     1.997714

# %%
# 적용된 수치형 데이터 시각화
for col in num_features:
    plt.figure(figsize=(3,3))
    sns.histplot(train_encoded_df[col], kde=True)
    plt.title(col)
    plt.show()

# %%
# 적용된 수치형 데이터 시각화
for col in num_features:
    plt.figure(figsize=(3,3))
    sns.histplot(test_encoded_df[col], kde=True)
    plt.title(col)
    plt.show()

# %%
plt.figure(figsize=(3,3))
sns.histplot(train_encoded_df['count'], kde=True)
plt.title('Count')
plt.show()

# %% [markdown]
# # 3. 데이터 분석

# %%
# 그룹별 평균을 barplot으로 시각화하는 패턴 만들기
def barplot_pattern(df, group_col, target='count', title=''):
    mean = df.groupby(group_col)[target].mean()
    sns.barplot(x=mean.index, y=mean.values)
    plt.title(title)
    plt.show()

# %% [markdown]
# ### 1. 상관관계 분석

# %%
# 상관관계 
corr = train_encoded_df.corr()

corr
# Out:
#               datetime      temp     atemp  humidity  windspeed    casual  \
# datetime      1.000000  0.181015  0.181849  0.032851  -0.052302  0.172734
# temp          0.181015  1.000000  0.984945 -0.064783   0.010197  0.467071
# atemp         0.181849  0.984945  1.000000 -0.043376  -0.027457  0.462039
# humidity      0.032851 -0.064783 -0.043376  1.000000  -0.242230 -0.348149
# windspeed    -0.052302  0.010197 -0.027457 -0.242230   1.000000  0.081862
# casual        0.172734  0.467071  0.462039 -0.348149   0.081862  1.000000
# registered    0.314879  0.318608  0.314668 -0.265479   0.090893  0.497259
# count         0.237444  0.376682  0.372254 -0.333226   0.117463  0.579068
# season_2     -0.130556  0.192603  0.204367 -0.031031   0.048791  0.132377
# season_3      0.122130  0.635972  0.607081  0.067381  -0.051988  0.187700
# season_4      0.373918 -0.266335 -0.245795  0.129096  -0.080654 -0.086293
# holiday_1     0.010989  0.000270 -0.005238  0.001949   0.001114  0.043790
# workingday_1 -0.003662  0.030067  0.024754 -0.010960   0.005648 -0.319085
# weather_2     0.026346 -0.047015 -0.040875  0.222486  -0.019820 -0.062219
# weather_3    -0.027403 -0.025759 -0.031196  0.295950   0.040402 -0.108871
# year          0.866604  0.061377  0.058681 -0.078730   0.005205  0.145305
# month         0.494155  0.257420  0.264016  0.204760  -0.116979  0.092646
# day           0.028564  0.015527  0.011843 -0.011315   0.050408  0.014099
# hour         -0.005669  0.145584  0.140486 -0.278150   0.133335  0.302114
# weekday      -0.004668 -0.038687 -0.040443 -0.026338  -0.013529  0.246905
#
#               registered     count  season_2  season_3  season_4  holiday_1  \
# datetime        0.314879  0.237444 -0.130556  0.122130  0.373918   0.010989
# temp            0.318608  0.376682  0.192603  0.635972 -0.266335   0.000270
# atemp           0.314668  0.372254  0.204367  0.607081 -0.245795  -0.005238
# humidity       -0.265479 -0.333226 -0.031031  0.067381  0.129096   0.001949
# windspeed       0.090893  0.117463  0.048791 -0.051988 -0.080654   0.001114
# casual          0.497259  0.579068  0.132377  0.187700 -0.086293   0.043790
# registered      1.000000  0.792133  0.046971  0.102144  0.056963  -0.020955
# count           0.792133  1.000000  0.059064  0.119958  0.038043  -0.001225
# season_2        0.046971  0.059064  1.000000 -0.335255 -0.335337  -0.038259
# season_3        0.102144  0.119958 -0.335255  1.000000 -0.335337   0.022781
# season_4        0.056963  0.038043 -0.335337 -0.335337  1.000000   0.022742
# holiday_1      -0.020955 -0.001225 -0.038259  0.022781  0.022742   1.000000
# workingday_1    0.119461 -0.015350  0.014657 -0.007158 -0.007012  -0.250486
# weather_2      -0.028997 -0.019171 -0.001718 -0.051928  0.045946   0.013859
# weather_3      -0.104936 -0.111516  0.006540 -0.013105  0.007263  -0.019519
# year            0.264275  0.178212 -0.002393 -0.001545 -0.002181   0.012037
# month           0.169473  0.163805 -0.255700  0.248302  0.753103   0.001706
# day             0.019111  0.019014  0.001009  0.000932  0.000506  -0.015880
# hour            0.380554  0.570633 -0.002684 -0.002561 -0.002915  -0.000339
# weekday        -0.084434  0.027318 -0.000837 -0.003585 -0.006545  -0.191876
#
#               workingday_1  weather_2  weather_3      year     month  \
# datetime         -0.003662   0.026346  -0.027403  0.866604  0.494155
# temp              0.030067  -0.047015  -0.025759  0.061377  0.257420
# atemp             0.024754  -0.040875  -0.031196  0.058681  0.264016
# humidity         -0.010960   0.222486   0.295950 -0.078730  0.204760
# windspeed         0.005648  -0.019820   0.040402  0.005205 -0.116979
# casual           -0.319085  -0.062219  -0.108871  0.145305  0.092646
# registered        0.119461  -0.028997  -0.104936  0.264275  0.169473
# count            -0.015350  -0.019171  -0.111516  0.178212  0.163805
# season_2          0.014657  -0.001718   0.006540 -0.002393 -0.255700
# season_3         -0.007158  -0.051928  -0.013105 -0.001545  0.248302
# season_4         -0.007012   0.045946   0.007263 -0.002181  0.753103
# holiday_1        -0.250486   0.013859  -0.019519  0.012037  0.001706
# workingday_1      1.000000   0.003361   0.036662 -0.002545 -0.003294
# weather_2         0.003361   1.000000  -0.173663  0.019119  0.018944
# weather_3         0.036662  -0.173663   1.000000 -0.030748 -0.000435
# year             -0.002545   0.019119  -0.030748  1.000000 -0.004786
# month            -0.003294   0.018944  -0.000435 -0.004786  1.000000
# day               0.009841   0.011997  -0.018958  0.001817  0.001947
# hour              0.002722  -0.050623   0.014056 -0.004320 -0.006681
# weekday          -0.704261  -0.035862  -0.026220 -0.003648 -0.002488
#
#                    day      hour   weekday
# datetime      0.028564 -0.005669 -0.004668
# temp          0.015527  0.145584 -0.038687
# atemp         0.011843  0.140486 -0.040443
# humidity     -0.011315 -0.278150 -0.026338
# windspeed     0.050408  0.133335 -0.013529
# casual        0.014099  0.302114  0.246905
# registered    0.019111  0.380554 -0.084434
# count         0.019014  0.570633  0.027318
# season_2      0.001009 -0.002684 -0.000837
# season_3      0.000932 -0.002561 -0.003585
# season_4      0.000506 -0.002915 -0.006545
# holiday_1    -0.015880 -0.000339 -0.191876
# workingday_1  0.009841  0.002722 -0.704261
# weather_2     0.011997 -0.050623 -0.035862
# weather_3    -0.018958  0.014056 -0.026220
# year          0.001817 -0.004320 -0.003648
# month         0.001947 -0.006681 -0.002488
# day           1.000000  0.001148 -0.011096
# hour          0.001148  1.000000 -0.002796
# weekday      -0.011096 -0.002796  1.000000

# %%
# 히트맵
plt.figure(figsize=(12, 12))
sns.heatmap(corr, annot=True, fmt=".2f", cmap='viridis')
# Out:
# <Axes: >

# %%
# 목표 변수 기준으로 상관관계

corr_target_data = corr['count'].sort_values(ascending=False)
corr_target_data
# Out:
# count           1.000000
# registered      0.792133
# casual          0.579068
# hour            0.570633
# temp            0.376682
# atemp           0.372254
# datetime        0.237444
# year            0.178212
# month           0.163805
# season_3        0.119958
# windspeed       0.117463
# season_2        0.059064
# season_4        0.038043
# weekday         0.027318
# day             0.019014
# holiday_1      -0.001225
# workingday_1   -0.015350
# weather_2      -0.019171
# weather_3      -0.111516
# humidity       -0.333226
# Name: count, dtype: float64

# %% [markdown]
# 상관관계 높은 순
#
# - registered : 등록된 사용자 수
#
# - casual : 등록되지 않은 사용자 수
#
#  **** count는 registered와 casual의 합이므로 상관관계가 높게 나오는 것은 구조적으로 당연한 것
#
# - hour : 시간대
#
# - temp : 실측온도
#
# - atemp : 체감온도
#
# - humidity : 습도 (음의 상관관계)

# %% [markdown]
#     연도별, 월별, 풍속, 날씨, 평일 vs 휴일 은 추가 확인
#
# season은 월별로 대체 가능
#
# day는 평일 vs 휴일로 대체 가능

# %% [markdown]
# ###  2. 시간대별 대여량 분석

# %%
# 시간대별 평균 대여량

analysis_df['hour'] = analysis_df['datetime'].dt.hour

hour_mean = analysis_df.groupby('hour', observed=False)['count'].mean()
hour_mean
# Out:
# hour
# 0      55.138462
# 1      33.859031
# 2      22.899554
# 3      11.757506
# 4       6.407240
# 5      19.767699
# 6      76.259341
# 7     213.116484
# 8     362.769231
# 9     221.780220
# 10    175.092308
# 11    210.674725
# 12    256.508772
# 13    257.787281
# 14    243.442982
# 15    254.298246
# 16    316.372807
# 17    468.765351
# 18    430.859649
# 19    315.278509
# 20    228.517544
# 21    173.370614
# 22    133.576754
# 23     89.508772
# Name: count, dtype: float64

# %%
# 시각화
barplot_pattern(analysis_df, 'hour', target='count', title='시간대별 자전거 이용량')

# %% [markdown]
# - 상대적으로 출퇴근 시간에 이용자들이 많은 것을 알 수 있다.

# %% [markdown]
# ### 3. 온도별 대여량 분석

# %%
# 실제 온도 구간화  
analysis_df['temp_group'] = pd.cut(
    analysis_df['temp'],
    bins=[-10, 0, 10, 20, 30, 40],
    labels=['0이하', '0~10', '10~20', '20~30', '30이상']
)

temp_mean = analysis_df.groupby('temp_group', observed=False)['count'].mean()
temp_mean
# Out:
# temp_group
# 0이하             NaN
# 0~10      73.185862
# 10~20    150.465053
# 20~30    223.411398
# 30이상     334.306516
# Name: count, dtype: float64

# %%
# 시각화
barplot_pattern(analysis_df, 'temp_group', target='count', title="실제온도별 자전거 이용량")
# Out:
# C:\Users\wina0\AppData\Local\Temp\ipykernel_1324\912854953.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean = df.groupby(group_col)[target].mean()

# %%
# 체감 온도 구간화  
analysis_df['atemp_group'] = pd.cut(
    analysis_df['atemp'],
    bins=[-10, 0, 10, 20, 30, 40],
    labels=['0이하', '0~10', '10~20', '20~30', '30이상']
)

atemp_mean = analysis_df.groupby('atemp_group', observed=False)['count'].mean()
atemp_mean
# Out:
# atemp_group
# 0이하             NaN
# 0~10      67.329289
# 10~20    125.206462
# 20~30    179.412210
# 30이상     290.191229
# Name: count, dtype: float64

# %%
# 시각화
barplot_pattern(analysis_df, 'atemp_group', target='count', title="체감온도별 자전거 이용량")
# Out:
# C:\Users\wina0\AppData\Local\Temp\ipykernel_1324\912854953.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean = df.groupby(group_col)[target].mean()

# %% [markdown]
# - 실제 온도와 체감 온도가 이용 평균에 미치는 영향은 비슷함 -> 모델 학습시 한개만 적용 예정
# - 온도가 낮을 때보다 높을 때, 이용자가 많은 것을 확인

# %% [markdown]
# ### 4. 습도별 대여량 분석

# %%
# 습도 구간화
analysis_df['humidity_group'] = pd.cut(
    analysis_df['humidity'],
    bins=[0, 30, 60, 100],
    labels=['습도 낮음', '습도 중간', '습도 높음']
)

humidity_mean = analysis_df.groupby('humidity_group', observed=False)['count'].mean()
humidity_mean
# Out:
# humidity_group
# 습도 낮음    292.291489
# 습도 중간    236.836306
# 습도 높음    146.371745
# Name: count, dtype: float64

# %%
# 시각화
barplot_pattern(analysis_df, 'humidity_group', target='count', title="습도별 자전거 이용량")
# Out:
# C:\Users\wina0\AppData\Local\Temp\ipykernel_1324\912854953.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean = df.groupby(group_col)[target].mean()

# %% [markdown]
# - 상대적으로 습도가 낮을 때, 이용자가 많은 것을 확인

# %% [markdown]
# ## 5. 연도별 대여량 분석

# %%
# 연도별 평균 대여량

year_mean = analysis_df.groupby('year', observed=False)['count'].mean()
year_mean
# Out:
# year
# 2011    144.223349
# 2012    238.560944
# Name: count, dtype: float64

# %%
# 시각화
barplot_pattern(analysis_df, 'year', target='count', title="연도별 자전거 이용량")

# %% [markdown]
# -> 2012년에 이용자들이 더 많았음.

# %% [markdown]
# ## 6. 월별 대여량 분석

# %%
# 월별 평균 대여량

month_mean = analysis_df.groupby('month', observed=False)['count'].mean()
month_mean
# Out:
# month
# 1      90.366516
# 2     110.003330
# 3     148.169811
# 4     184.160616
# 5     219.459430
# 6     242.031798
# 7     235.325658
# 8     234.118421
# 9     233.805281
# 10    227.699232
# 11    193.677278
# 12    175.614035
# Name: count, dtype: float64

# %%
# 시각화
barplot_pattern(analysis_df, 'month', target='count', title="월별 자전거 이용량")

# %% [markdown]
# - 겨울보다 여름~가을에 상대적으로 이용자가 많음.

# %% [markdown]
# ## 7. 풍속별 대여량 분석

# %%
# 추세선 시각화
sns.regplot(
    data=analysis_df,
    x='windspeed',
    y='count',
    order=2,
    scatter_kws={'alpha':0.2}
)
# Out:
# <Axes: xlabel='windspeed', ylabel='count'>

# %% [markdown]
# - 바람이 거의 없을 때보다 바람이 적당할 때 대여량이 많음
#
# - 풍속이 강해지면 대여량이 줄어듬

# %% [markdown]
# ## 8. 날씨별 대여량 분석

# %%
# 날씨별 대여량
weather_mean = analysis_df.groupby('weather', observed=False)['count'].mean()
weather_mean
# Out:
# weather
# 1    205.236791
# 2    178.955540
# 3    118.846333
# 4    164.000000
# Name: count, dtype: float64

# %%
# weather 4인 데이터량이 부족하여 drop하기
analysis_df = analysis_df[analysis_df['weather'] != 4]
analysis_df['weather'].value_counts()

# 날씨별 대여량
weather_mean = analysis_df.groupby('weather', observed=False)['count'].mean()
weather_mean
# Out:
# weather
# 1    205.236791
# 2    178.955540
# 3    118.846333
# Name: count, dtype: float64

# %%
# 시각화
barplot_pattern(analysis_df, 'weather', target='count', title="날씨별 자전거 이용량")

# %% [markdown]
# - 날씨가 좋지 않을때보다 날씨가 좋을때 대여량이 높음.
#
# - 폭우/ 폭설시에는 이용을 거의 안함.

# %%
# 바람에 대하여 교란 변수(날씨)를 통제하여 시각화
sns.lmplot(
    data=analysis_df,
    x='windspeed',
    y='count',
    col='weather'
)

# %% [markdown]
# - 풍속은 날씨 상태와 상호작용하는 변수로 작용하여, 날씨가 안좋으면 바람과 대여량의 관계는 줄어듬.

# %% [markdown]
# ## 9. 평일과 휴일별 대여량 분석

# %%
# 평일과 휴일별 평균 대여량
holiday_mean = analysis_df.groupby('holiday', observed=False)['count'].mean()
holiday_mean
# Out:
# holiday
# 0    191.744278
# 1    185.877814
# Name: count, dtype: float64

# %%
# 시각화
barplot_pattern(analysis_df, 'holiday', target='count', title="평일과 휴일별 자전거 이용량")

# %% [markdown]
# - 유의미한 차이 없음

# %% [markdown]
# # 4. 데이터 모델링

# %% [markdown]
# ### 1. 학습 데이터 정리

# %%
# 학습 데이터 정리

X = train_encoded_df.drop(columns=['datetime', 'casual', 'registered', 'count'])
y = train_encoded_df['count']

print(X.shape)
print(y.shape)

# 테스트셋 분리(20 : 80)
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, random_state=5)
# Out:
# (10885, 16)
# (10885,)

# %% [markdown]
# ### 2. 다중 선형 회귀

# %%
# 다중 선형 회귀 모델 학습
linear_model = LinearRegression()
linear_model.fit(X_train, y_train)

# 예측
y_train_linear_pred = linear_model.predict(X_train)
y_valid_linear_pred = linear_model.predict(X_valid)

train_rmsle_linear = rmsle(y_train, y_train_linear_pred)
valid_rmsle_linear = rmsle(y_valid, y_valid_linear_pred)

# RMSLE 평가
print(f"훈련 RMSLE= {train_rmsle_linear:.4f}, 검증 RMSLE= {valid_rmsle_linear:.4f}, 차이= {valid_rmsle_linear-train_rmsle_linear:.4f}")
# Out:
# 훈련 RMSLE= 0.9646, 검증 RMSLE= 0.9853, 차이= 0.0207

# %% [markdown]
# -> 다중선형회귀의 결과값은 다른 모델과 비교용

# %% [markdown]
# ### 3. 다항 회귀

# %%
results_poly = []

for i in [2, 3]:

    # 다항 변환
    poly = PolynomialFeatures(i)
    X_train_poly = poly.fit_transform(X_train)
    X_valid_poly = poly.transform(X_valid)

    # 다항회귀 모델 학습
    model = LinearRegression()
    model.fit(X_train_poly, y_train)

    # 예측
    y_train_pred = model.predict(X_train_poly)
    y_valid_pred = model.predict(X_valid_poly)

    # RMSLE 평가
    train_rmsle = rmsle(y_train, y_train_pred)
    valid_rmsle = rmsle(y_valid, y_valid_pred)

    # 결과 저장
    results_poly.append({
        'degree': i,
        'train_rmsle': train_rmsle,
        'valid_rmsle': valid_rmsle
    })

    print(f'차수={i} | 훈련 RMSLE={train_rmsle:.4f}, 검증 RMSLE={valid_rmsle:.4f}, 차이 = {valid_rmsle-train_rmsle:.4f}')
# Out:
# 차수=2 | 훈련 RMSLE=0.8027, 검증 RMSLE=0.8229, 차이 = 0.0202
# 차수=3 | 훈련 RMSLE=0.6888, 검증 RMSLE=0.7481, 차이 = 0.0594

# %% [markdown]
# -> 2차는 다중 선형회귀 모델보다 좋아졌고, 훈련 결과와 검증 결과의 차이가 거의 없음
#
# -> 3차는 모델은 더 좋아졌으나, 훈련 결과와 검증 결과가 차이가 나기 시작
#
# -> 4차는 모델 복잡도가 증가해 과적합 가능성이 높아, 실험 대상에서 제외

# %% [markdown]
# ### 3. 로지스틱회귀

# %% [markdown]
# 현재 회귀문제이므로 생략

# %% [markdown]
# ### 4. 정규화

# %% [markdown]
# #### 1. L2 정규화

# %%
results_l2 = []

for i in [2, 3]:
    for a in [0.1, 1, 10, 50, 100]:

        # 다항 변환
        poly_L2 = PolynomialFeatures(i)
        X_train_poly_L2 = poly_L2.fit_transform(X_train)
        X_valid_poly_L2 = poly_L2.transform(X_valid)

        # Ridge 모델
        ridge_model = Ridge(alpha=a, max_iter=5000)
        ridge_model.fit(X_train_poly_L2, y_train)

        # 예측
        y_train_pred_L2 = ridge_model.predict(X_train_poly_L2)
        y_valid_pred_L2 = ridge_model.predict(X_valid_poly_L2)

        # RMSLE 계산
        train_rmsle = rmsle(y_train, y_train_pred_L2)
        valid_rmsle = rmsle(y_valid, y_valid_pred_L2)

        # 결과 저장
        results_l2.append({
            'degree': i,
            'alpha': a,
            'train_rmsle': train_rmsle,
            'valid_rmsle': valid_rmsle,
        })

        print(f'차수={i}, 알파={a}, train={train_rmsle:.4f}, valid={valid_rmsle:.4f}, 차이={valid_rmsle-train_rmsle:.4f}')
# Out:
# 차수=2, 알파=0.1, train=0.8057, valid=0.8229, 차이=0.0172
# 차수=2, 알파=1, train=0.8061, valid=0.8232, 차이=0.0172
# 차수=2, 알파=10, train=0.8065, valid=0.8239, 차이=0.0174
# 차수=2, 알파=50, train=0.8072, valid=0.8247, 차이=0.0175
# 차수=2, 알파=100, train=0.8076, valid=0.8252, 차이=0.0175
# 차수=3, 알파=0.1, train=0.6942, valid=0.7411, 차이=0.0469
# 차수=3, 알파=1, train=0.6962, valid=0.7393, 차이=0.0432
# 차수=3, 알파=10, train=0.6994, valid=0.7378, 차이=0.0384
# 차수=3, 알파=50, train=0.7026, valid=0.7368, 차이=0.0343
# 차수=3, 알파=100, train=0.7041, valid=0.7367, 차이=0.0325

# %% [markdown]
# #### 2. L1 정규화

# %%
results_l1 = []

def L1check(i,a):
    # 다항 변환
    poly_L1 = PolynomialFeatures(i)
    X_train_poly_L1 = poly_L1.fit_transform(X_train)
    X_valid_poly_L1 = poly_L1.transform(X_valid)

    # Lasso 모델 (L1)
    lasso_model = Lasso(alpha=a, max_iter=10000, tol=1e-2)
    lasso_model.fit(X_train_poly_L1, y_train)

    # 예측
    y_train_pred_L1 = lasso_model.predict(X_train_poly_L1)
    y_valid_pred_L1 = lasso_model.predict(X_valid_poly_L1)

    # RMSLE 계산
    train_rmsle = rmsle(y_train, y_train_pred_L1)
    valid_rmsle = rmsle(y_valid, y_valid_pred_L1)

    results_l1.append({
        'degree': i,
        'alpha': a,
        'train_rmsle': train_rmsle,
        'valid_rmsle': valid_rmsle
    })

    print(f'차수={i}, 알파={a}, train={train_rmsle:.4f}, valid={valid_rmsle:.4f}, 차이={valid_rmsle-train_rmsle:.4f}')


for i in [2, 3]:
    if i == 2:
        for a in [0.1, 1, 10, 50, 100]:
            L1check(i, a)
    else:
        for a in [10, 50, 100]:   # L2 결과를 보고, L1 에서의 3차는 큰 알파값만 실험함.
            L1check(i,a)
# Out:
# 차수=2, 알파=0.1, train=0.8263, valid=0.8397, 차이=0.0134
# 차수=2, 알파=1, train=0.8319, valid=0.8427, 차이=0.0108
# 차수=2, 알파=10, train=0.8712, valid=0.8872, 차이=0.0160
# 차수=2, 알파=50, train=0.9722, valid=0.9966, 차이=0.0244
# 차수=2, 알파=100, train=0.9772, valid=1.0018, 차이=0.0246
# 차수=3, 알파=10, train=0.7645, valid=0.7803, 차이=0.0159
# 차수=3, 알파=50, train=0.7963, valid=0.8121, 차이=0.0158
# 차수=3, 알파=100, train=0.8212, valid=0.8365, 차이=0.0153

# %% [markdown]
# ## 5. 모델 선정

# %%
# 다중 선형 회귀 DF화
linear_df = pd.DataFrame([{
    'model': 'Linear',
    'degree': 1,
    'regularization': 'None',
    'alpha': 'None',
    'train_rmsle': train_rmsle_linear,
    'valid_rmsle': valid_rmsle_linear
}])

# 디항 선형 회귀 DF화
poly_df = pd.DataFrame(results_poly)
poly_df['model'] = 'Polynomial'
poly_df['regularization'] = 'None'
poly_df['alpha'] = 'None'

# L2 DF화
ridge_df = pd.DataFrame(results_l2)
ridge_df['model'] = 'Polynomial'
ridge_df['regularization'] = 'L2'

# L1 DF화
lasso_df = pd.DataFrame(results_l1)
lasso_df['model'] = 'Polynomial'
lasso_df['regularization'] = 'L1'

# 데이터 합치기
all_results = pd.concat([linear_df, poly_df, ridge_df, lasso_df], ignore_index=True)

# 훈련rmsle와 검증rmsle 차이 추가
all_results["diff"] = all_results['valid_rmsle']-all_results['train_rmsle']

# 정렬하기
all_results[['model', 'regularization', 'degree', 'alpha', 'train_rmsle', 'valid_rmsle', 'diff']].sort_values('valid_rmsle')
# Out:
#          model regularization  degree  alpha  train_rmsle  valid_rmsle  \
# 12  Polynomial             L2       3  100.0     0.704145     0.736654
# 11  Polynomial             L2       3   50.0     0.702588     0.736841
# 10  Polynomial             L2       3   10.0     0.699410     0.737830
# 9   Polynomial             L2       3    1.0     0.696160     0.739332
# 8   Polynomial             L2       3    0.1     0.694193     0.741134
# 2   Polynomial           None       3   None     0.688754     0.748108
# 18  Polynomial             L1       3   10.0     0.764462     0.780317
# 19  Polynomial             L1       3   50.0     0.796304     0.812080
# 1   Polynomial           None       2   None     0.802673     0.822912
# 3   Polynomial             L2       2    0.1     0.805717     0.822949
# 4   Polynomial             L2       2    1.0     0.806056     0.823223
# 5   Polynomial             L2       2   10.0     0.806549     0.823935
# 6   Polynomial             L2       2   50.0     0.807183     0.824651
# 7   Polynomial             L2       2  100.0     0.807625     0.825164
# 20  Polynomial             L1       3  100.0     0.821215     0.836494
# 13  Polynomial             L1       2    0.1     0.826289     0.839725
# 14  Polynomial             L1       2    1.0     0.831901     0.842735
# 15  Polynomial             L1       2   10.0     0.871202     0.887164
# 0       Linear           None       1   None     0.964606     0.985297
# 16  Polynomial             L1       2   50.0     0.972173     0.996592
# 17  Polynomial             L1       2  100.0     0.977217     1.001821
#
#         diff
# 12  0.032509
# 11  0.034253
# 10  0.038420
# 9   0.043172
# 8   0.046941
# 2   0.059354
# 18  0.015854
# 19  0.015775
# 1   0.020239
# 3   0.017232
# 4   0.017166
# 5   0.017386
# 6   0.017468
# 7   0.017539
# 20  0.015279
# 13  0.013436
# 14  0.010834
# 15  0.015963
# 0   0.020691
# 16  0.024419
# 17  0.024605

# %% [markdown]
#     -> 선택 모델 : 다항회귀 모델 + 3차 + 알파값100 + L2 정규화

# %% [markdown]
# ## 6. 하이퍼 파타미터 탐색 (Optuna)

# %%
# Optuna
def objective(trial):

    # 탐색할 하이퍼파라미터
    degree = trial.suggest_int('degree', 2, 3)
    alpha = trial.suggest_float('alpha', 0.01, 100, log=True)

    # 다항 변환
    poly = PolynomialFeatures(degree)
    X_train_poly = poly.fit_transform(X_train)
    X_valid_poly = poly.transform(X_valid)

    # Ridge 모델
    model = Ridge(alpha)
    model.fit(X_train_poly, y_train)

    # 예측
    y_valid_pred = model.predict(X_valid_poly)

    return rmsle(y_valid, y_valid_pred)

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)

print(f'study.best_params: {study.best_params}')
print(f'study.best_value: {study.best_value}')
# Out:
# [I 2026-01-23 20:28:30,867] A new study created in memory with name: no-name-8892638b-fabb-40e9-98ca-332d4ebda2bb
# [I 2026-01-23 20:28:30,900] Trial 0 finished with value: 0.8235216658840536 and parameters: {'degree': 2, 'alpha': 2.891006106532948}. Best is trial 0 with value: 0.8235216658840536.
# [I 2026-01-23 20:28:31,079] Trial 1 finished with value: 0.7386425401728407 and parameters: {'degree': 3, 'alpha': 3.1179092910664443}. Best is trial 1 with value: 0.7386425401728407.
# [I 2026-01-23 20:28:31,257] Trial 2 finished with value: 0.7384823031418177 and parameters: {'degree': 3, 'alpha': 3.9728880735019123}. Best is trial 2 with value: 0.7384823031418177.
# [I 2026-01-23 20:28:31,446] Trial 3 finished with value: 0.7403525988285665 and parameters: {'degree': 3, 'alpha': 0.2469103078951892}. Best is trial 2 with value: 0.7384823031418177.
# [I 2026-01-23 20:28:31,609] Trial 4 finished with value: 0.741029496408351 and parameters: {'degree': 3, 'alpha': 0.11283552634604854}. Best is trial 2 with value: 0.7384823031418177.
# [I 2026-01-23 20:28:31,634] Trial 5 finished with value: 0.8234868929476933 and parameters: {'degree': 2, 'alpha': 2.5916058102165067}. Best is trial 2 with value: 0.7384823031418177.
# [I 2026-01-23 20:28:31,659] Trial 6 finished with value: 0.8234376523450218 and parameters: {'degree': 2, 'alpha': 2.2115876351726045}. Best is trial 2 with value: 0.7384823031418177.
# [I 2026-01-23 20:28:31,826] Trial 7 finished with value: 0.7405927783495573 and parameters: {'degree': 3, 'alpha': 0.18640877014906018}. Best is trial 2 with value: 0.7384823031418177.
# [I 2026-01-23 20:28:31,849] Trial 8 finished with value: 0.8229233232594428 and parameters: {'degree': 2, 'alpha': 0.04020539205654211}. Best is trial 2 with value: 0.7384823031418177.
# [I 2026-01-23 20:28:31,874] Trial 9 finished with value: 0.8231603164679202 and parameters: {'degree': 2, 'alpha': 0.7482229811255572}. Best is trial 2 with value: 0.7384823031418177.
# [I 2026-01-23 20:28:32,045] Trial 10 finished with value: 0.7368314214516682 and parameters: {'degree': 3, 'alpha': 51.194376224729304}. Best is trial 10 with value: 0.7368314214516682.
# [I 2026-01-23 20:28:32,229] Trial 11 finished with value: 0.7367835733138443 and parameters: {'degree': 3, 'alpha': 57.85001902421843}. Best is trial 11 with value: 0.7367835733138443.
# [I 2026-01-23 20:28:32,403] Trial 12 finished with value: 0.7366770567659948 and parameters: {'degree': 3, 'alpha': 84.65605221693475}. Best is trial 12 with value: 0.7366770567659948.
# [I 2026-01-23 20:28:32,568] Trial 13 finished with value: 0.7366622315792365 and parameters: {'degree': 3, 'alpha': 92.83899785702697}. Best is trial 13 with value: 0.7366622315792365.
# [I 2026-01-23 20:28:32,736] Trial 14 finished with value: 0.737370986922369 and parameters: {'degree': 3, 'alpha': 19.397202392348017}. Best is trial 13 with value: 0.7366622315792365.
# [I 2026-01-23 20:28:32,903] Trial 15 finished with value: 0.7376985315182607 and parameters: {'degree': 3, 'alpha': 12.028858452496083}. Best is trial 13 with value: 0.7366622315792365.
# [I 2026-01-23 20:28:33,071] Trial 16 finished with value: 0.7427174008154849 and parameters: {'degree': 3, 'alpha': 0.010179624853512046}. Best is trial 13 with value: 0.7366622315792365.
# [I 2026-01-23 20:28:33,241] Trial 17 finished with value: 0.7367159925773381 and parameters: {'degree': 3, 'alpha': 71.43700047365816}. Best is trial 13 with value: 0.7366622315792365.
# [I 2026-01-23 20:28:33,410] Trial 18 finished with value: 0.7375506265207148 and parameters: {'degree': 3, 'alpha': 14.863967949514288}. Best is trial 13 with value: 0.7366622315792365.
# [I 2026-01-23 20:28:33,579] Trial 19 finished with value: 0.7371412192190986 and parameters: {'degree': 3, 'alpha': 27.97151595605661}. Best is trial 13 with value: 0.7366622315792365.
# [I 2026-01-23 20:28:33,605] Trial 20 finished with value: 0.8251236313016221 and parameters: {'degree': 2, 'alpha': 95.37110691590783}. Best is trial 13 with value: 0.7366622315792365.
# [I 2026-01-23 20:28:33,769] Trial 21 finished with value: 0.7366563381594453 and parameters: {'degree': 3, 'alpha': 97.43960952342016}. Best is trial 21 with value: 0.7366563381594453.
# [I 2026-01-23 20:28:33,932] Trial 22 finished with value: 0.7378702306214159 and parameters: {'degree': 3, 'alpha': 9.453876469547337}. Best is trial 21 with value: 0.7366563381594453.
# [I 2026-01-23 20:28:34,100] Trial 23 finished with value: 0.7370399014874459 and parameters: {'degree': 3, 'alpha': 33.38508879633245}. Best is trial 21 with value: 0.7366563381594453.
# [I 2026-01-23 20:28:34,270] Trial 24 finished with value: 0.7380154595627595 and parameters: {'degree': 3, 'alpha': 7.7234729490209855}. Best is trial 21 with value: 0.7366563381594453.
# [I 2026-01-23 20:28:34,436] Trial 25 finished with value: 0.736659035305967 and parameters: {'degree': 3, 'alpha': 95.17811140338054}. Best is trial 21 with value: 0.7366563381594453.
# [I 2026-01-23 20:28:34,603] Trial 26 finished with value: 0.7370121443040512 and parameters: {'degree': 3, 'alpha': 35.13134630652225}. Best is trial 21 with value: 0.7366563381594453.
# [I 2026-01-23 20:28:34,772] Trial 27 finished with value: 0.7395309449523547 and parameters: {'degree': 3, 'alpha': 0.7298208156082666}. Best is trial 21 with value: 0.7366563381594453.
# [I 2026-01-23 20:28:34,935] Trial 28 finished with value: 0.7381994419380209 and parameters: {'degree': 3, 'alpha': 5.97116588002677}. Best is trial 21 with value: 0.7366563381594453.
# [I 2026-01-23 20:28:34,963] Trial 29 finished with value: 0.8243305620470787 and parameters: {'degree': 2, 'alpha': 27.64883039959934}. Best is trial 21 with value: 0.7366563381594453.
# [I 2026-01-23 20:28:35,130] Trial 30 finished with value: 0.7366558863113601 and parameters: {'degree': 3, 'alpha': 97.85197203149872}. Best is trial 30 with value: 0.7366558863113601.
# [I 2026-01-23 20:28:35,296] Trial 31 finished with value: 0.7366553991949957 and parameters: {'degree': 3, 'alpha': 98.30924091655048}. Best is trial 31 with value: 0.7366553991949957.
# [I 2026-01-23 20:28:35,464] Trial 32 finished with value: 0.736925896818319 and parameters: {'degree': 3, 'alpha': 41.555778118294036}. Best is trial 31 with value: 0.7366553991949957.
# [I 2026-01-23 20:28:35,633] Trial 33 finished with value: 0.7372637881458595 and parameters: {'degree': 3, 'alpha': 22.902734837855803}. Best is trial 31 with value: 0.7366553991949957.
# [I 2026-01-23 20:28:35,799] Trial 34 finished with value: 0.7367928062355003 and parameters: {'degree': 3, 'alpha': 56.43140092930274}. Best is trial 31 with value: 0.7366553991949957.
# [I 2026-01-23 20:28:35,966] Trial 35 finished with value: 0.736654293873503 and parameters: {'degree': 3, 'alpha': 99.40202287199399}. Best is trial 35 with value: 0.736654293873503.
# [I 2026-01-23 20:28:36,129] Trial 36 finished with value: 0.7391425617548781 and parameters: {'degree': 3, 'alpha': 1.371195151821659}. Best is trial 35 with value: 0.736654293873503.
# [I 2026-01-23 20:28:36,293] Trial 37 finished with value: 0.737516575663927 and parameters: {'degree': 3, 'alpha': 15.6189309353836}. Best is trial 35 with value: 0.736654293873503.
# [I 2026-01-23 20:28:36,468] Trial 38 finished with value: 0.7383525220863034 and parameters: {'degree': 3, 'alpha': 4.801864856025495}. Best is trial 35 with value: 0.736654293873503.
# [I 2026-01-23 20:28:36,638] Trial 39 finished with value: 0.7368441873215699 and parameters: {'degree': 3, 'alpha': 49.66600449006891}. Best is trial 35 with value: 0.736654293873503.
# [I 2026-01-23 20:28:36,665] Trial 40 finished with value: 0.8245188551209618 and parameters: {'degree': 2, 'alpha': 39.970587612900324}. Best is trial 35 with value: 0.736654293873503.
# [I 2026-01-23 20:28:36,833] Trial 41 finished with value: 0.7366541727228123 and parameters: {'degree': 3, 'alpha': 99.52700293277199}. Best is trial 41 with value: 0.7366541727228123.
# [I 2026-01-23 20:28:37,003] Trial 42 finished with value: 0.7367645484107127 and parameters: {'degree': 3, 'alpha': 61.03135247085252}. Best is trial 41 with value: 0.7366541727228123.
# [I 2026-01-23 20:28:37,183] Trial 43 finished with value: 0.736658125647728 and parameters: {'degree': 3, 'alpha': 95.9064031395586}. Best is trial 41 with value: 0.7366541727228123.
# [I 2026-01-23 20:28:37,357] Trial 44 finished with value: 0.7372611030060514 and parameters: {'degree': 3, 'alpha': 23.00034600648844}. Best is trial 41 with value: 0.7366541727228123.
# [I 2026-01-23 20:28:37,524] Trial 45 finished with value: 0.740144195434831 and parameters: {'degree': 3, 'alpha': 0.31759547985323616}. Best is trial 41 with value: 0.7366541727228123.
# [I 2026-01-23 20:28:37,690] Trial 46 finished with value: 0.7368011052936799 and parameters: {'degree': 3, 'alpha': 55.21682942070252}. Best is trial 41 with value: 0.7366541727228123.
# [I 2026-01-23 20:28:37,854] Trial 47 finished with value: 0.7415672453346019 and parameters: {'degree': 3, 'alpha': 0.05996577454181604}. Best is trial 41 with value: 0.7366541727228123.
# [I 2026-01-23 20:28:38,022] Trial 48 finished with value: 0.736745973446284 and parameters: {'degree': 3, 'alpha': 64.5480035321255}. Best is trial 41 with value: 0.7366541727228123.
# [I 2026-01-23 20:28:38,049] Trial 49 finished with value: 0.8245036761381317 and parameters: {'degree': 2, 'alpha': 38.89296964036753}. Best is trial 41 with value: 0.7366541727228123.
# study.best_params: {'degree': 3, 'alpha': 99.52700293277199}
# study.best_value: 0.7366541727228123

# %% [markdown]
# GridSearch는 전수 탐색이라 비효율적이라 판단하여 Optuna를 사용함.
#
# 처음부터 train데이터와 test데이터가 분리되어 있어
#
# OptunaSearchCV 대신 create_study 기반으로 objective 함수를 정의하여 사용했음.

# %% [markdown]
# # 5. 최종 test

# %%
# test 데이터 정리
X_test = test_encoded_df.select_dtypes(exclude=['datetime64'])

# train 기준으로 test 컬럼 맞추기
X_test = X_test.reindex(columns=X_train.columns, fill_value=0)

# 1train + valid 합치기 (최종 학습용)
X_train_final = np.vstack([X_train, X_valid])
y_train_final = np.concatenate([y_train, y_valid])

# 최종 파라미터 - Optuna 결과 반영
final_degree = study.best_params['degree']
final_alpha = study.best_params['alpha']

# 다항 변환 
poly = PolynomialFeatures(final_degree)
X_train_final_poly = poly.fit_transform(X_train_final)
X_test_poly = poly.transform(X_test)

# 최종 L2 학습
final_model = Ridge(alpha=final_alpha)
final_model.fit(X_train_final_poly, y_train_final)

# test 예측
y_test_pred_log = final_model.predict(X_test_poly)
y_test_pred = np.expm1(y_test_pred_log)

# 음수는 0으로 클리핑
y_test_pred = np.maximum(0, y_test_pred)

# 결과 확인

print("음수 개수:", (y_test_pred < 0).sum())
print("NaN 개수:", np.isnan(y_test_pred).sum())
print("inf 개수:", np.isinf(y_test_pred).sum())
# Out:
# c:\Users\wina0\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2684: UserWarning: X has feature names, but PolynomialFeatures was fitted without feature names
#   warnings.warn(
# 음수 개수: 0
# NaN 개수: 0
# inf 개수: 0

# %% [markdown]
# 로그변환을 이용하여 일부 음수 예측이 발생해 물리적으로 불가능한 값은 0으로 보정하였음.

# %%
# 기존 test_df 확인하기
test_df.head()
# Out:
#               datetime  season  holiday  workingday  weather      temp  \
# 0  2011-01-20 00:00:00       1        0           1        1 -1.228414
# 1  2011-01-20 01:00:00       1        0           1        1 -1.228414
# 2  2011-01-20 02:00:00       1        0           1        1 -1.228414
# 3  2011-01-20 03:00:00       1        0           1        1 -1.228414
# 4  2011-01-20 04:00:00       1        0           1        1 -1.228414
#
#       atemp  humidity  windspeed
# 0 -1.450292 -0.305883   3.295937
# 1 -1.182421 -0.305883   0.000000
# 2 -1.182421 -0.305883   0.000000
# 3 -1.271515 -0.305883   2.485023
# 4 -1.271515 -0.305883   2.485023

# %%
# test_df에 최종 예측값 추가하기
test_df['pred_count'] = y_test_pred

# %%
# 최종 결과 확인
test_df.head()
# Out:
#               datetime  season  holiday  workingday  weather      temp  \
# 0  2011-01-20 00:00:00       1        0           1        1 -1.228414
# 1  2011-01-20 01:00:00       1        0           1        1 -1.228414
# 2  2011-01-20 02:00:00       1        0           1        1 -1.228414
# 3  2011-01-20 03:00:00       1        0           1        1 -1.228414
# 4  2011-01-20 04:00:00       1        0           1        1 -1.228414
#
#       atemp  humidity  windspeed  pred_count
# 0 -1.450292 -0.305883   3.295937    2.603510
# 1 -1.182421 -0.305883   0.000000    2.175894
# 2 -1.182421 -0.305883   0.000000    2.774060
# 3 -1.271515 -0.305883   2.485023    5.484985
# 4 -1.271515 -0.305883   2.485023    7.449287

# %%
# 학습데이터의 목표변수와 모델을 이용하여 찾은 최종 예측값 분포 확인하기

sns.kdeplot(np.expm1(train_df['count']), label='학습용', fill=True)
sns.kdeplot(test_df['pred_count'], label='최종 예측', fill=True)
plt.legend()
plt.title("학습 데이터와 예측 데이터의 분포 비교")
plt.show()

# %% [markdown]
# # 6. 결론

# %% [markdown]
# 다중선형회귀를 기준으로 다항회귀와 정규화를 적용하여,
#
# valid_rmsle 기준으로 Optuna를 활용해
#
#     다항회귀 3차 + L2 Ridge(알파값=100) 모델을 최종 선택했다.
#
# 초반에 나눴던 train데이터와 valid데이터를 통합한 뒤
#
# 선택한 모델로 재학습하고 test 데이터에 대한 최종 예측을 수행하였고,
#
# 음수값이 일부 발생하였으나, 물리적으로 공유 자전거 수요에서 음수값은 나올 수 없으므로
#
# 0으로 보정하고, 결측값이나 무한대값이 없음을 확인하였다.
#
# 최종적으로 학습 데이터와 예측 데이터의 분포를 비교하니, 비슷한 분포를 보였다.
